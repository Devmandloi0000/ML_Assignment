# %%
import pandas as pd

# %%
df = pd.read_csv("E:\\8. INEURON\\2. September_batch\\machine_learning_working_projects\\complete_task_25_aug\\notebook\\data\\finalTrain.csv")

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df.drop("ID",axis=1,inplace=True)

# %%
for i in df.columns:
    print("column name is :-",i)
    print(f"data type of the column :-{df[i].dtype}")
    print(f"column unique values :- {df[i].nunique()}")
    print(f"missing values are :- {df[i].isna().sum()}")
    print("="*45)
# Out:
# column name is :- Delivery_person_ID
# data type of the column :-object
# column unique values :- 1320
# missing values are :- 0
# ...
# column name is :- Delivery_person_Age
# data type of the column :-float64
# column unique values :- 22
# missing values are :- 1854
# ...
# column name is :- Delivery_person_Ratings
# data type of the column :-float64
# column unique values :- 28
# missing values are :- 1908
# ...
# column name is :- Restaurant_latitude
# data type of the column :-float64
# column unique values :- 657
# missing values are :- 0
# ...
# column name is :- Restaurant_longitude
# data type of the column :-float64
# column unique values :- 518
# missing values are :- 0
# ...
# column name is :- Delivery_location_latitude
# data type of the column :-float64
# column unique values :- 4373
# missing values are :- 0
# ...
# column name is :- Delivery_location_longitude
# data type of the column :-float64
# column unique values :- 4373
# missing values are :- 0
# ...
# column name is :- Order_Date
# ...

# %%
keys=df.groupby('Delivery_person_ID')['Restaurant_longitude'].mean().sort_values().index

# %%
values=df.groupby('Delivery_person_ID')['Restaurant_longitude'].mean().sort_values().values

# %%
mapping = dict(zip(keys,values))

# %%
df['Delivery_person_ID']=df['Delivery_person_ID'].map(mapping)

# %%
df.head()
# Out:
#    Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0           78.046106                 36.0                      4.2
# 1           76.307589                 21.0                      4.7
# 2           73.916619                 23.0                      4.7
# 3           75.809346                 34.0                      4.3
# 4           80.372929                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df['Delivery_person_Age']
# Out:
# 0        36.0
# 1        21.0
# 2        23.0
# 3        34.0
# 4        24.0
#          ...
# 45579    30.0
# 45580    21.0
# 45581    30.0
# 45582    20.0
# 45583    23.0
# Name: Delivery_person_Age, Length: 45584, dtype: float64

# %%
df['Delivery_person_Age'].mode()
# Out:
# 0    35.0
# Name: Delivery_person_Age, dtype: float64

# %%
df['Delivery_person_Age']=df['Delivery_person_Age'].fillna(35.0)

# %%
df['Delivery_person_Age'].isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0           78.046106                 36.0                      4.2
# 1           76.307589                 21.0                      4.7
# 2           73.916619                 23.0                      4.7
# 3           75.809346                 34.0                      4.3
# 4           80.372929                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df['Delivery_person_Ratings'].mode()
# Out:
# 0    4.8
# Name: Delivery_person_Ratings, dtype: float64

# %%
df['Delivery_person_Ratings']=df['Delivery_person_Ratings'].fillna(4.8)

# %%
df['Delivery_person_Ratings'].isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0           78.046106                 36.0                      4.2
# 1           76.307589                 21.0                      4.7
# 2           73.916619                 23.0                      4.7
# 3           75.809346                 34.0                      4.3
# 4           80.372929                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %% [markdown]
# ORDER_DATE :- datatype of this column is object so we should convert this into int type and make them as a single column for data month and yearwise

# %%
df['Order_Date']
# Out:
# 0        12-02-2022
# 1        13-02-2022
# 2        04-03-2022
# 3        13-02-2022
# 4        14-02-2022
#             ...
# 45579    24-03-2022
# 45580    16-02-2022
# 45581    11-03-2022
# 45582    07-03-2022
# 45583    02-03-2022
# Name: Order_Date, Length: 45584, dtype: object

# %%
df['Order_day']=df['Order_Date'].str.split("-").str[0]

# %%
df['Order_month']=df['Order_Date'].str.split("-").str[1]

# %%
df['Order_year']=df['Order_Date'].str.split("-").str[2]

# %%
df.drop("Order_Date",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0           78.046106                 36.0                      4.2
# 1           76.307589                 21.0                      4.7
# 2           73.916619                 23.0                      4.7
# 3           75.809346                 34.0                      4.3
# 4           80.372929                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked  \
# ...

# %% [markdown]
# Time_Orderd and Time_Order_picked this two column are ain task which provide information regarding the time taken to picked order

# %% [markdown]
# but in this  there are many data is missing which is not in time format some data is in float format so we should convert this first into int then extract the data and them map accoding to picked time

# %%
df['Time_Orderd']
# Out:
# 0        21:55
# 1        14:55
# 2        17:30
# 3        09:20
# 4        19:50
#          ...
# 45579    11:35
# 45580    19:55
# 45581    23:50
# 45582    13:35
# 45583    17:10
# Name: Time_Orderd, Length: 45584, dtype: object

# %%
df['Time_Order_picked']
# Out:
# 0           22:10
# 1           15:05
# 2           17:40
# 3           09:30
# 4           20:05
#            ...
# 45579       11:45
# 45580       20:10
# 45581    24:05:00
# 45582       13:40
# 45583       17:15
# Name: Time_Order_picked, Length: 45584, dtype: object

# %%
df['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', nan, '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
# ...

# %%
df['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25',
#        '0.458333333', '19:15', '16:55', '11:40', '15:15', '22:55',
#        '22:25', '20:55', '23:05', '0.75', '0.958333333', '09:40', '20:20',
#        '22:35', '0.916666667', '23:55', '15:40', '10:30', '0.875',
#        '10:50', '16:05', '20:15', '12:15', '15:45', '22:15', '10:45',
#        '15:30', '24:05:00', '21:25', '12:45', '21:15', '18:20', '18:25',
#        '11:50', '12:50', '10:55', '21:40', '10:20', '17:55', '23:50',
#        '12:55', '24:10:00', '10:40', '0.375', '20:45', '0.833333333',
#        '23:15', '22:20', '21:05', '0.708333333', '24:15:00', '21:20',
# ...

# %%
df["Time_Orderd"].str.split(":").str[0].unique().astype(float)
# Out:
# array([21.        , 14.        , 17.        ,  9.        , 19.        ,
#        20.        , 22.        ,  8.        , 12.        , 18.        ,
#        23.        , 13.        ,  0.45833333,  0.95833333,         nan,
#        10.        ,  0.79166667, 16.        , 11.        , 15.        ,
#         0.875     ,  1.        ,  0.375     ,  0.625     ,  0.83333333,
#         0.66666667,  0.75      ,  0.41666667,  0.91666667,  0.5       ,
#         0.70833333,  0.54166667,  0.58333333])

# %%
df["Time_Orderd"].str.split(":").str[1].unique().astype(float)
# Out:
# array([55., 30., 20., 50., 25., 40., 15., 35., nan, 45., 10.])

# %%
df[df['Time_Orderd'] == "0.583333333"]
# Out:
#        Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 1065            72.795503                 39.0                      4.7
# 2770            72.813074                 33.0                      4.7
# 3960            76.630028                 20.0                      4.9
# 5043             0.000000                 28.0                      4.8
# 5640            80.236442                 33.0                      4.8
# ...                   ...                  ...                      ...
# 40661           77.401663                 24.0                      4.9
# 41817           80.250744                 32.0                      5.0
# 44113           73.905101                 38.0                      4.7
# 44133           75.776649                 20.0                      4.1
# 44816           85.390464                 38.0                      4.0
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# ...

# %%
my_data = []
for i in df["Time_Orderd"].str.split(":").str[0].unique().astype(float):
    if i < 1:
        my_data.append(i)


print(my_data)
# Out:
# [0.458333333, 0.958333333, 0.791666667, 0.875, 0.375, 0.625, 0.833333333, 0.666666667, 0.75, 0.416666667, 0.916666667, 0.5, 0.708333333, 0.541666667, 0.583333333]

# %% [markdown]
# here in this we create a dict where floating value haves the same times therfore we set them in dict and mapping it into the time_order

# %%
my_mapping = {"0.458333333" : "11:00", "0.958333333":"23:00", "0.791666667":"19:00", "0.875":"21:00", "0.375":"09:00", "0.625":"15:00", "0.833333333":"20:00", "0.666666667":"16:00", "0.75":"18:00", "0.416666667":"10:00", "0.916666667":"22:00", "0.5":"12:00", "0.708333333":"17:00", "0.541666667":"13:00", "0.583333333":"14:00"}

# %%
df.drop('Time_Orderd_one',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0           78.046106                 36.0                      4.2
# 1           76.307589                 21.0                      4.7
# 2           73.916619                 23.0                      4.7
# 3           75.809346                 34.0                      4.3
# 4           80.372929                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked  \
# ...

# %%
my_mapping
# Out:
# {'0.458333333': '11:00',
#  '0.958333333': '23:00',
#  '0.791666667': '19:00',
#  '0.875': '21:00',
#  '0.375': '09:00',
#  '0.625': '15:00',
#  '0.833333333': '20:00',
#  '0.666666667': '16:00',
#  '0.75': '18:00',
#  '0.416666667': '10:00',
#  '0.916666667': '22:00',
#  '0.5': '12:00',
#  '0.708333333': '17:00',
#  '0.541666667': '13:00',
#  '0.583333333': '14:00'}

# %%
def func():
    for i in df['Time_Orderd']:
        if i == '0.458333333':
            return "11:00"
        elif i == '0.958333333':
            return "23:00"
        else:
            pass

# %%
df["Time_Orderd_hour"]=df["Time_Orderd"].str.split(":").str[0].astype(float)

# %%
df['Time_Orderd'].apply(func())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 df['Time_Orderd'].apply(func())
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\apply.py:1120, in SeriesApply.apply(self)
#    1116     return self.apply_multiple()
#    1118 if isinstance(self.f, str):
#    1119     # if we are a string, try to dispatch
# -> 1120     return self.apply_str()
# ...

# %%
df.head()
# Out:
#    Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0           78.046106                 36.0                      4.2
# 1           76.307589                 21.0                      4.7
# 2           73.916619                 23.0                      4.7
# 3           75.809346                 34.0                      4.3
# 4           80.372929                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked  \
# ...

# %%
df['Time_Orderd_hour'].unique()
# Out:
# array([21.        , 14.        , 17.        ,  9.        , 19.        ,
#        20.        , 22.        ,  8.        , 12.        , 18.        ,
#        23.        , 13.        ,  0.45833333,  0.95833333,         nan,
#        10.        ,  0.79166667, 16.        , 11.        , 15.        ,
#         0.875     ,  1.        ,  0.375     ,  0.625     ,  0.83333333,
#         0.66666667,  0.75      ,  0.41666667,  0.91666667,  0.5       ,
#         0.70833333,  0.54166667,  0.58333333])
